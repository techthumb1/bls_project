# %% [markdown]
# # Bureau of Labor and Statistics
#
# ### EDA
#
# - **Consumer Price Index**
# - **Consumer Expenditure Survey**
# - **Consumer Purchase Survey**
#
# Dataset is comprised of components of economic effects that lead to inflation and the effects of inflation for the consumer.
#
# This notebook will consist of performing expoloratory data analysis on the selected areas of focus. Analysis will assist in attaining greater insight of the data and how we should approach model training.
# ***
# **Import our Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %% [markdown]
# **Basic Pandas functions**

# %%
df = pd.read_csv('/Users/jasonrobinson/Documents/Projects/bls_project/data_2/SeriesReport-cpi-market-mix.48.csv')
print(df.shape)
df.T
# Out:
# (75, 49)
#               0        1        2        3        4        5        6   \
# Year      1948.0   1949.0   1950.0   1951.0   1952.0   1953.0   1954.0
# Jan_U       23.7     24.0     23.5     25.4     26.5     26.6     26.9
# Jan_W       23.8     24.2     23.7     25.5     26.6     26.8     27.1
# Jan_Emp  58061.0  58175.0  57635.0  59636.0  60460.0  61600.0  60024.0
# Jan_LF   60095.0  60771.0  61661.0  61941.0  62432.0  63439.0  63101.0
# Feb_U       23.5     23.8     23.5     25.7     26.3     26.5     26.9
# Feb_W       23.6     23.9     23.6     25.9     26.5     26.7     27.1
# Feb_Emp  58196.0  58208.0  57751.0  59661.0  60462.0  61884.0  60663.0
# Feb_LF   60524.0  61057.0  61687.0  61778.0  62419.0  63520.0  63994.0
# Mar_U       23.4     23.8     23.6     25.8     26.3     26.6     26.9
# Mar_W       23.6     24.0     23.7     26.0     26.5     26.7     27.0
# Mar_Emp  57671.0  58043.0  57728.0  60401.0  59908.0  62010.0  60186.0
# ...

# %% [markdown]
# **Summary Statistics**

# %% [markdown]
# **Basic quick visualization**

# %% [markdown]
# **Import our Libraries**

# %% [markdown]
# **Import our Libraries**

# %% [markdown]
# **Import our Libraries**
