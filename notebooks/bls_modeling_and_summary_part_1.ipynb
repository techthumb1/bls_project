# %% [markdown]
# # PART III - Modeling and Summary
#
# In this section we will use methods best for time series prediction or forecasting.We will examine a **10, 20, 50, 100** year range of data selection.
#
# ### Measures and Characteristics
#
# Here we have our measures for which we will reduce down to categories:
# > Consumer Asset and Liabilities<br>
# > Consumer Spending<br>
# > Pay and Benefits<br>
# > People and Families

# %%
#pip install pandas-datareader
#!pip install fredpy

# %%
import pandas as pd
import numpy as np
import datetime
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Use BLS API to examine CPI
cpi = web.DataReader(['CPI', 'fred'], start=datetime.datetime(2018, 1, 1), end=datetime.datetime(2020, 12, 2))

print(cpi.head())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/q3/0g1f31211lbgj741dfjd4r5c0000gn/T/ipykernel_5709/552039919.py in <module>
#       1 # Use BLS API to examine CPI
# ----> 2 cpi = web.DataReader(['CPI', 'fred'], start=datetime.datetime(2018, 1, 1), end=datetime.datetime(2020, 12, 2))
#       3
#       4 print(cpi.head())
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     212                 else:
#     213                     kwargs[new_arg_name] = new_arg_value
# --> 214             return func(*args, **kwargs)
#     215
#     216         return cast(F, wrapper)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     365     if data_source not in expected_source:
# ...

# %% [markdown]
# start = datetime.datetime(1948, 1, 1)
# end = datetime.datetime(2021, 1, 27)
# gdp = web.DataReader('GDP', 'fred', start, end)
# gdp.loc['2021-01-01']
#
# # Multiple series:
# inflation = web.DataReader(['CPIAUCSL', 'CPILFESL'], 'fred', start, end)
# inflation.head()

# %%
462c9e430957fbc1f835c6bc7e7c3e64

# %% [markdown]
# # FRED API

# %%
import fredpy as fp
import matplotlib.pyplot as plt
plt.style.use('classic')
# %matplotlib inline

fp.api_key = '462c9e430957fbc1f835c6bc7e7c3e64 '

# %%
u = fp.series('UNRATE')
plt.plot(u.data.index,u.data.values,'-',lw=3,alpha = 0.65)
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /var/folders/q3/0g1f31211lbgj741dfjd4r5c0000gn/T/ipykernel_2720/167451065.py in <module>
# ----> 1 u = fp.series('UNRATE')
#       2 plt.plot(u.data.index,u.data.values,'-',lw=3,alpha = 0.65)
#       3 plt.grid()
#
# /opt/anaconda3/lib/python3.8/site-packages/fredpy/__init__.py in __init__(self, series_id, observation_date)
#     119              }
#     120
# --> 121             r = fred_api_request(api_key=api_key,path=path,parameters=parameters)
#     122             results = r.json()
#     123
#
# /opt/anaconda3/lib/python3.8/site-packages/fredpy/__init__.py in fred_api_request(api_key, path, parameters)
#     975
#     976         else:
# --> 977             r.raise_for_status()
#     978
#     979         request_count+=1
#
# /opt/anaconda3/lib/python3.8/site-packages/requests/models.py in raise_for_status(self)
#     939
# ...

# %%
from pandas_datareader.fred import FredReader

# %%
fr = FredReader()

# %% [markdown]
# ## BLS API

# %%
# Work with multliple series 
import requests

response = requests.get("https://api.bls.gov/publicAPI/v2/timeseries/data/LNS14000000", "startyear":"2020")
# Out:
#   File "/var/folders/q3/0g1f31211lbgj741dfjd4r5c0000gn/T/ipykernel_2720/1756031267.py", line 4
#     response = requests.get("https://api.bls.gov/publicAPI/v2/timeseries/data/LNS14000000", "startyear":"2020")
#                                                                                                        ^
# SyntaxError: invalid syntax

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# {'status': 'REQUEST_SUCCEEDED', 'responseTime': 187, 'message': [], 'Results': {'series': [{'seriesID': 'LNS14000000', 'data': [{'year': '2022', 'period': 'M02', 'periodName': 'February', 'latest': 'true', 'value': '3.8', 'footnotes': [{}]}, {'year': '2022', 'period': 'M01', 'periodName': 'January', 'value': '4.0', 'footnotes': [{}]}, {'year': '2021', 'period': 'M12', 'periodName': 'December', 'value': '3.9', 'footnotes': [{}]}, {'year': '2021', 'period': 'M11', 'periodName': 'November', 'value': '4.2', 'footnotes': [{}]}, {'year': '2021', 'period': 'M10', 'periodName': 'October', 'value': '4.6', 'footnotes': [{}]}, {'year': '2021', 'period': 'M09', 'periodName': 'September', 'value': '4.7', 'footnotes': [{}]}, {'year': '2021', 'period': 'M08', 'periodName': 'August', 'value': '5.2', 'footnotes': [{}]}, {'year': '2021', 'period': 'M07', 'periodName': 'July', 'value': '5.4', 'footnotes': [{}]}, {'year': '2021', 'period': 'M06', 'periodName': 'June', 'value': '5.9', 'footnotes': [{}]},
# ...

# %%
import json

def jprint(response):
    # create a formatted string of the Python JSON object
    text = json.dumps(response, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# {
#     "Results": {
#         "series": [
#             {
#                 "data": [
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "latest": "true",
#                         "period": "M02",
#                         "periodName": "February",
#                         "value": "3.8",
#                         "year": "2022"
#                     },
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M01",
#                         "periodName": "January",
#                         "value": "4.0",
#                         "year": "2022"
#                     },
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M12",
# ...

# %%
surveys = requests.get('https://api.bls.gov/publicAPI/v2/surveys')

# %%
print(surveys.json())
# Out:
# {'status': 'REQUEST_SUCCEEDED', 'responseTime': 27, 'message': [], 'Results': {'survey': [{'survey_abbreviation': 'AP', 'survey_name': 'Consumer Price Index - Average Price Data'}, {'survey_abbreviation': 'BD', 'survey_name': 'Business Employment Dynamics'}, {'survey_abbreviation': 'BG', 'survey_name': 'Collective Bargaining Agreements-State and Local Government'}, {'survey_abbreviation': 'BP', 'survey_name': 'Collective Bargaining Agreements-Private Sector'}, {'survey_abbreviation': 'CC', 'survey_name': 'Employer Costs for Employee Compensation'}, {'survey_abbreviation': 'CD', 'survey_name': 'Nonfatal cases involving days away from work: selected characteristics'}, {'survey_abbreviation': 'CE', 'survey_name': 'Employment, Hours, and Earnings from the Current Employment Statistics survey (National)'}, {'survey_abbreviation': 'CF', 'survey_name': 'Census of Fatal Occupational Injuries'}, {'survey_abbreviation': 'CH', 'survey_name': 'Nonfatal cases involving days away from work: select
# ...

# %%
def jprint(surveys):
    # create a formatted string of the Python JSON object
    text = json.dumps(surveys, sort_keys=True, indent=4)
    print(text)

jprint(response.json())
# Out:
# {
#     "Results": {
#         "series": [
#             {
#                 "data": [
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "latest": "true",
#                         "period": "M02",
#                         "periodName": "February",
#                         "value": "3.8",
#                         "year": "2022"
#                     },
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M01",
#                         "periodName": "January",
#                         "value": "4.0",
#                         "year": "2022"
#                     },
#                     {
#                         "footnotes": [
#                             {}
#                         ],
#                         "period": "M12",
# ...

# %%
surveys.footnotes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/q3/0g1f31211lbgj741dfjd4r5c0000gn/T/ipykernel_2720/666914884.py in <module>
# ----> 1 surveys.footnotes
#
# AttributeError: 'Response' object has no attribute 'footnotes'
